# %%
#!pip install scipy==1.12

# %%
# Import necessary libraries
from numpy import triu
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import re
from gensim.models import Word2Vec
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# Download NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/matteorigat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/matteorigat/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Define the list of cooking techniques
TECHNIQUES_LIST = [
    'bake', 'boil', 'braise', 'broil', 'fry', 'grill', 'roast', 'saute', 'simmer',
    'steam', 'stew'
]

# Define a new technique mapping based on TECHNIQUES_LIST
technique_mapping = {
    'bake': 'bake',
    'barbecue': 'grill',
    'blanch': 'boil',
    'blend': 'combine',
    'boil': 'boil',
    'braise': 'braise',
    'brine': 'marinate',
    'broil': 'broil',
    'caramelize': 'saute',
    'combine': 'combine',
    'crock pot': 'slow cook',
    'crush': 'puree',
    'deglaze': 'saute',
    'devein': 'prepare',
    'dice': 'prepare',
    'distill': 'boil',
    'drain': 'boil',
    'emulsify': 'mix',
    'ferment': 'bake',
    'freeze': 'refrigerate',
    'fry': 'fry',
    'grate': 'saute',
    'griddle': 'prepare',
    'grill': 'grill',
    'knead': 'prepare',
    'leaven': 'bake',
    'marinate': 'marinate',
    'mash': 'stew',
    'melt': 'melt',
    'microwave': 'stew',
    'parboil': 'bake',
    'pickle': 'pickling',
    'poach': 'stew',
    'pour': 'combine',
    'pressure cook': 'bake',
    'puree': 'puree',
    'refrigerate': 'refrigerate',
    'roast': 'roast',
    'saute': 'saute',
    'scald': 'fry',
    'scramble': 'combine',
    'shred': 'puree',
    'simmer': 'simmer',
    'skillet': 'saute',
    'slow cook': 'slow cook',
    'smoke': 'grill',
    'smooth': 'stew',
    'soak': 'bake',
    'sous-vide': 'combine',
    'steam': 'steam',
    'stew': 'stew',
    'strain': 'bake',
    'tenderize': 'fry',
    'thicken': 'boil',
    'toast': 'grill',
    'toss': 'stew',
    'whip': 'grill',
    'whisk': 'stew'
}

# %%
file_path = "dataset/RAW_merged.csv"
data = pd.read_csv(file_path)

# %%
# # Function to convert one-hot encoded techniques back to list format
# def one_hot_to_list(row):
#     techniques_one_hot = eval(row['techniques'])
#     techniques_list = [TECHNIQUES_LIST[i] for i, val in enumerate(techniques_one_hot) if val == 1]
#     return techniques_list
# 
# # Apply the function to each row to convert one-hot encoded techniques to list format
# data['techniques'] = data.apply(one_hot_to_list, axis=1)

# %%
# Initialize lists to store raw ingredients and techniques
raw_ingredients = []
raw_techniques = []

# Extract ingredients and techniques from each recipe
for index, row in data.iterrows():
    ingredients = eval(row['ingredients'])
    raw_ingredients.extend(ingredients)

    techniques = eval(row['techniques_list'])
    raw_techniques.extend(techniques)

# %%
# Clean out non-letter or space symbols and collapse the list into a collection of ingredients
# regex = re.compile('[^a-zA-Z ]')
# ingredients_full = [regex.sub('', item.lower()).strip() for item in raw_ingredients]
# raw_ingredients = np.unique(ingredients_full)
# print(len(raw_ingredients))
# for item in raw_ingredients:
#    print(item)

# %%
# Look at words in the data to clean unnecessary differentiators
# words=[x for item in raw_ingredients for x in item.split(' ') if len(x)>1]
# for word in words:
#    print(word)

# %%
# Construct a frequence dictionary and create a dataset of words to drop
# uniqueFrequencies = {i:words.count(i) for i in words}
# dropWords=[k for k in uniqueFrequencies.keys() if uniqueFrequencies[k]==1]\
# +['yellow','black','red','green','white','purple','cloves','and','cook','drain','allpurpose','purpose','all','pitted','crumbles','powder', 'whole', 'extract', 'sweet', 'baby', 'bakin', 'brow', 'canned', 'celery']
# len(dropWords)

# %%
# Count frequencies of ingredients and techniques
ingredient_counts = Counter(raw_ingredients)
technique_counts = Counter(raw_techniques)

# %%
# Print out statistics
print('Total number of unique ingredients:', len(ingredient_counts))
print('Total number of unique techniques:', len(technique_counts))

# Example of how to print the most common ingredients
print('\nTop most common ingredients:')
for ingredient, count in ingredient_counts.most_common(1000):
    print(f'{ingredient}: {count}')
# 
# # Example of how to print the most common techniques
# print('\nTop 10 most common techniques:')
# for technique, count in technique_counts.most_common(10):
#     print(f'{technique}: {count}')

# # Assuming you also want to print out the distribution of cuisines based on the number of steps
# steps_counts = Counter(data['steps'].apply(lambda x: len(eval(x))))
# print('\nDistribution of recipes based on number of steps:')
# for steps, count in steps_counts.items():
#     print(f'{steps} steps: {count} recipes')
# Out:
# Total number of unique ingredients: 13627
# Total number of unique techniques: 57
#
# Top most common ingredients:
# salt: 66469
# butter: 43862
# sugar: 33884
# onion: 31624
# water: 25953
# eggs: 25636
# olive oil: 25598
# flour: 20672
# milk: 20035
# garlic cloves: 19506
# pepper: 18522
# brown sugar: 15217
# garlic: 14312
# baking powder: 13650
# egg: 13428
# salt and pepper: 12625
# all-purpose flour: 12575
# parmesan cheese: 11921
# baking soda: 11276
# lemon juice: 11185
# vanilla: 10629
# vegetable oil: 10593
# black pepper: 10077
# cinnamon: 9958
# tomatoes: 9583
# sour cream: 9222
# garlic powder: 8535
# oil: 7927
# garlic clove: 7843
# cheddar cheese: 7639
# celery: 7547
# onions: 7512
# cream cheese: 7433
# honey: 7414
# vanilla extract: 7356
# soy sauce: 7043
# mayonnaise: 6967
# chicken broth: 6332
# worcestershire sauce: 6221
# paprika: 6185
# fresh parsley: 6145
# extra virgin olive oil: 5650
# cornstarch: 5597
# parsley: 5494
# bacon: 5468
# unsalted butter: 5414
# chili powder: 5406
# carrots: 5320
# potatoes: 5272
# carrot: 5238
# fresh ground black pepper: 5194
# ground cinnamon: 5098
# green onions: 4798
# nutmeg: 4766
# ground beef: 4729
# cayenne pepper: 4696
# walnuts: 4622
# ground cumin: 4619
# pecans: 4618
# red onion: 4604
# green onion: 4570
# dijon mustard: 4507
# granulated sugar: 4244
# margarine: 4240
# fresh lemon juice: 4061
# powdered sugar: 3901
# mozzarella cheese: 3882
# dried oregano: 3730
# zucchini: 3658
# kosher salt: 3625
# green pepper: 3623
# raisins: 3524
# orange juice: 3521
# tomato sauce: 3496
# red bell pepper: 3474
# heavy cream: 3437
# canola oil: 3284
# fresh ginger: 3256
# oregano: 3247
# fresh cilantro: 3244
# boneless skinless chicken breasts: 3207
# chicken stock: 3177
# cumin: 3137
# ketchup: 3094
# tomato paste: 3061
# balsamic vinegar: 3026
# ground black pepper: 2903
# fresh basil: 2895
# buttermilk: 2850
# lime juice: 2817
# ground ginger: 2810
# diced tomatoes: 2797
# ginger: 2797
# cilantro: 2702
# dried thyme: 2647
# vinegar: 2636
# green bell pepper: 2625
# dried basil: 2609
# red wine vinegar: 2585
# onion powder: 2573
# white sugar: 2507
# fresh ground pepper: 2492
# curry powder: 2380
# whole wheat flour: 2352
# egg whites: 2351
# sesame oil: 2340
# bay leaf: 2328
# dry mustard: 2317
# dry white wine: 2280
# whipping cream: 2276
# crushed red pepper flakes: 2270
# thyme: 2254
# salsa: 2230
# salt & freshly ground black pepper: 2227
# white wine: 2204
# sea salt: 2203
# light brown sugar: 2187
# bananas: 2185
# garlic salt: 2184
# cheese: 2180
# mushrooms: 2176
# breadcrumbs: 2174
# ground nutmeg: 2168
# lemon: 2152
# chicken breasts: 2136
# basil: 2131
# lean ground beef: 2130
# confectioners' sugar: 2125
# shortening: 2116
# white pepper: 2094
# boiling water: 2093
# nuts: 2066
# sharp cheddar cheese: 2056
# feta cheese: 2029
# cider vinegar: 2023
# semi-sweet chocolate chips: 2023
# red pepper flakes: 1951
# monterey jack cheese: 1946
# black beans: 1918
# seasoning salt: 1871
# scallions: 1846
# cream of mushroom soup: 1845
# chocolate chips: 1832
# peanut butter: 1825
# red pepper: 1808
# fresh lime juice: 1800
# apples: 1775
# swiss cheese: 1757
# salt & pepper: 1752
# half-and-half: 1734
# fresh mushrooms: 1734
# cucumber: 1730
# evaporated milk: 1728
# bay leaves: 1711
# tabasco sauce: 1698
# skim milk: 1675
# cooking spray: 1667
# sesame seeds: 1663
# ground cloves: 1653
# cooked chicken: 1652
# white vinegar: 1642
# mushroom: 1640
# hot sauce: 1629
# black olives: 1624
# italian seasoning: 1618
# yellow onion: 1611
# beef broth: 1605
# chicken: 1605
# sliced mushrooms: 1603
# shallots: 1597
# cream: 1577
# lemon, juice of: 1574
# banana: 1567
# egg yolks: 1549
# maple syrup: 1537
# shallot: 1510
# cold water: 1505
# bread: 1501
# boneless skinless chicken breast halves: 1488
# almond extract: 1488
# shrimp: 1472
# avocado: 1469
# green chilies: 1466
# fresh thyme: 1461
# lettuce: 1452
# cabbage: 1441
# ground coriander: 1439
# cocoa: 1432
# lemon zest: 1432
# chives: 1416
# sweetened condensed milk: 1410
# flour tortillas: 1401
# celery ribs: 1400
# cayenne: 1375
# cooked rice: 1371
# ham: 1364
# cherry tomatoes: 1349
# plain yogurt: 1346
# turmeric: 1346
# molasses: 1333
# fresh rosemary: 1329
# hot water: 1318
# cream of chicken soup: 1318
# almonds: 1303
# frozen peas: 1288
# pine nuts: 1287
# capers: 1286
# broccoli: 1268
# apple: 1259
# rolled oats: 1250
# green beans: 1242
# dark brown sugar: 1235
# coconut: 1235
# corn: 1224
# barbecue sauce: 1222
# orange zest: 1221
# crushed pineapple: 1213
# whole milk: 1205
# bell pepper: 1203
# potato: 1185
# peanut oil: 1184
# scallion: 1182
# sweet potatoes: 1182
# egg white: 1178
# rice vinegar: 1173
# allspice: 1171
# coconut milk: 1170
# fresh dill: 1168
# red potatoes: 1159
# rice: 1148
# cornmeal: 1128
# white wine vinegar: 1128
# rosemary: 1124
# warm water: 1120
# red wine: 1118
# fresh chives: 1104
# gingerroot: 1097
# vegetable broth: 1096
# cocoa powder: 1079
# whipped cream: 1072
# cool whip: 1067
# cooking oil: 1053
# dried cranberries: 1050
# mustard: 1041
# hot pepper sauce: 1040
# boneless skinless chicken breast: 1039
# jalapeno pepper: 1024
# prepared mustard: 1018
# chickpeas: 1007
# of fresh mint: 1002
# ice: 1001
# beer: 999
# spinach: 997
# dried parsley: 997
# pineapple juice: 993
# sweet onion: 992
# apple cider vinegar: 987
# blueberries: 985
# ricotta cheese: 982
# slivered almonds: 982
# plain flour: 979
# fish sauce: 974
# applesauce: 964
# vegetable stock: 964
# blue cheese: 962
# sliced almonds: 952
# hard-boiled eggs: 948
# fresh spinach: 933
# frozen chopped spinach: 929
# strawberries: 923
# dry sherry: 912
# dried rosemary: 910
# icing sugar: 907
# flat leaf parsley: 898
# spaghetti: 895
# pasta: 894
# ground allspice: 894
# plum tomatoes: 894
# lime: 886
# clove: 884
# pork chops: 869
# french bread: 863
# caster sugar: 862
# elbow macaroni: 858
# white onion: 858
# asparagus: 856
# red onions: 855
# salmon fillets: 855
# ground pepper: 851
# romaine lettuce: 849
# crushed tomatoes: 846
# cauliflower: 844
# spaghetti sauce: 837
# pork tenderloin: 835
# light corn syrup: 834
# kidney beans: 832
# dry breadcrumbs: 832
# fresh strawberries: 832
# pure vanilla extract: 832
# low sodium chicken broth: 826
# white bread: 826
# coriander: 816
# egg yolk: 803
# celery seed: 795
# jalapeno: 791
# apple juice: 786
# ground red pepper: 781
# vanilla ice cream: 779
# yeast: 778
# lemons: 774
# unsweetened cocoa powder: 772
# coarse salt: 770
# baby carrots: 770
# strawberry: 768
# red bell peppers: 766
# vodka: 765
# avocados: 758
# splenda sugar substitute: 756
# active dry yeast: 756
# cinnamon stick: 755
# ground turkey: 754
# orange: 754
# fresh garlic: 750
# oatmeal: 750
# peanuts: 749
# chili sauce: 748
# baby spinach: 746
# yellow cake mix: 744
# basil leaves: 742
# cucumbers: 741
# pumpkin: 740
# frozen corn: 729
# green peppers: 727
# fresh oregano: 725
# cooked ham: 723
# bread flour: 722
# orange rind: 718
# taco seasoning: 714
# nonfat milk: 712
# salt and black pepper: 712
# stewed tomatoes: 710
# creamy peanut butter: 709
# peaches: 708
# velveeta cheese: 702
# low sodium soy sauce: 702
# dry red wine: 701
# flaked coconut: 700
# lemon, zest of: 697
# broccoli florets: 696
# tortilla chips: 694
# cottage cheese: 692
# sherry wine: 690
# cream of tartar: 690
# leeks: 686
# brandy: 682
# beef stock: 678
# oats: 677
# hoisin sauce: 672
# half-and-half cream: 669
# corn tortillas: 666
# heavy whipping cream: 664
# lime, juice of: 659
# graham cracker crumbs: 655
# eggplant: 648
# quick-cooking oats: 646
# celery salt: 639
# dates: 639
# russet potatoes: 637
# cracked black pepper: 635
# boneless chicken breasts: 635
# jalapeno peppers: 634
# cinnamon sticks: 628
# baking potatoes: 625
# ground cardamom: 620
# chopped tomatoes: 620
# dill weed: 617
# whole kernel corn: 615
# lemon peel: 614
# roma tomatoes: 613
# frozen spinach: 612
# unsweetened applesauce: 603
# fresh coarse ground black pepper: 602
# hamburger buns: 600
# provolone cheese: 596
# butternut squash: 595
# american cheese: 594
# yellow cornmeal: 594
# light soy sauce: 589
# egg noodles: 586
# sage: 583
# fresh basil leaf: 581
# ground pork: 580
# ice cubes: 580
# fresh blueberries: 579
# sunflower seeds: 574
# tomato juice: 573
# jalapenos: 571
# poultry seasoning: 567
# cloves: 566
# large shrimp: 566
# crabmeat: 565
# cumin seed: 565
# rice wine vinegar: 564
# penne pasta: 563
# cajun seasoning: 563
# artichoke hearts: 562
# garam masala: 562
# pumpkin pie spice: 561
# prepared horseradish: 560
# pepperoni: 557
# taco seasoning mix: 557
# goat cheese: 556
# ground turmeric: 554
# pinto beans: 551
# rum: 551
# light cream: 550
# couscous: 549
# sweet red pepper: 548
# oranges: 547
# linguine: 544
# egg substitute: 543
# tuna: 541
# long grain rice: 541
# leek: 541
# golden raisin: 540
# fresh orange juice: 536
# lime zest: 534
# lemon rind: 533
# dill: 533
# dried onion flakes: 528
# yellow bell pepper: 527
# onion soup mix: 526
# nonstick cooking spray: 526
# pineapple: 526
# tomato puree: 523
# corn syrup: 523
# liquid smoke: 521
# semisweet chocolate: 521
# catsup: 521
# granny smith apples: 521
# spring onions: 520
# mustard seeds: 519
# fresh basil leaves: 517
# brown rice: 513
# medium shrimp: 513
# sauerkraut: 513
# corn flakes: 512
# kalamata olive: 510
# fresh coriander: 509
# whole cloves: 509
# chicken wings: 509
# pesto sauce: 508
# yellow squash: 507
# celery rib: 507
# splenda granular: 506
# parsley flakes: 503
# fresh green beans: 503
# ice cube: 501
# bell peppers: 500
# low-fat milk: 499
# pecan halves: 496
# lemon pepper: 496
# black peppercorns: 495
# oyster sauce: 495
# peas: 493
# refried beans: 493
# fresh gingerroot: 491
# dried apricot: 491
# fresh mint leaves: 491
# mango: 489
# chicken breast: 487
# apple cider: 487
# green olives: 486
# caraway seed: 486
# cannellini beans: 486
# tequila: 485
# diced green chilies: 485
# mashed potatoes: 484
# cornflour: 484
# mandarin oranges: 482
# soymilk: 482
# minced garlic cloves: 480
# garbanzo beans: 479
# green cabbage: 479
# romano cheese: 479
# cranberries: 476
# white chocolate chips: 476
# shredded cheddar cheese: 475
# mustard powder: 473
# grape tomatoes: 473
# green bell peppers: 472
# hamburger: 472
# button mushrooms: 471
# yogurt: 471
# orange marmalade: 471
# yellow onions: 471
# chicken thighs: 471
# red kidney beans: 469
# pumpkin puree: 468
# old fashioned oats: 467
# prosciutto: 465
# orzo pasta: 461
# old bay seasoning: 460
# white rice: 459
# tomato soup: 458
# whipped topping: 456
# beef: 455
# pizza sauce: 453
# seasoning: 451
# chocolate syrup: 450
# cooked bacon: 449
# light sour cream: 446
# cake flour: 445
# cashews: 443
# italian sausage: 440
# wheat germ: 439
# sun-dried tomato: 438
# dark rum: 437
# light mayonnaise: 436
# bean sprouts: 435
# boneless skinless chicken thighs: 435
# sweet potato: 433
# fresh cranberries: 432
# limes: 428
# yellow mustard: 427
# fresh parsley leaves: 426
# shredded coconut: 425
# quick oats: 425
# marjoram: 425
# lemon wedge: 425
# pears: 424
# pineapple chunks: 423
# raspberries: 422
# baby spinach leaves: 421
# snow peas: 420
# horseradish: 419
# whole wheat bread: 419
# macaroni: 417
# 2% low-fat milk: 416
# panko breadcrumbs: 416
# red peppers: 415
# monterey jack pepper cheese: 413
# mint: 412
# dried marjoram: 410
# salad oil: 409
# canned pumpkin: 409
# iceberg lettuce: 408
# teriyaki sauce: 407
# fresh sage: 405
# italian dressing: 404
# roasted red pepper: 403
# fennel seed: 403
# white flour: 403
# ground chuck: 401
# italian seasoned breadcrumbs: 400
# dried parsley flakes: 400
# milk chocolate chips: 398
# unsweetened cocoa: 397
# roasted red peppers: 397
# cream of celery soup: 394
# reduced-sodium chicken broth: 394
# cooked chicken breasts: 393
# butterscotch chips: 392
# marshmallows: 391
# parmigiano-reggiano cheese: 390
# dry onion soup mix: 388
# miracle whip: 388
# chopped tomato: 387
# tahini: 385
# ranch dressing: 385
# angel hair pasta: 382
# self-rising flour: 382
# frozen mixed vegetables: 381
# basmati rice: 380
# instant vanilla pudding: 378
# cherry pie filling: 377
# dried tarragon: 377
# eggplants: 373
# lettuce leaves: 373
# maraschino cherry: 372
# fresh tarragon: 371
# bittersweet chocolate: 369
# dried sage: 369
# pasta sauce: 369
# chicken bouillon cubes: 368
# whole tomatoes: 368
# gruyere cheese: 368
# chicken pieces: 367
# firm tofu: 365
# self raising flour: 365
# lentils: 365
# onion salt: 361
# cranberry juice: 361
# bourbon: 359
# 1% low-fat milk: 358
# part-skim mozzarella cheese: 357
# bisquick: 356
# orange peel: 356
# condensed cream of mushroom soup: 355
# refrigerated crescent dinner rolls: 355
# rhubarb: 354
# sun-dried tomatoes: 354
# new potatoes: 353
# reduced sodium soy sauce: 353
# vanilla essence: 353
# dark chocolate: 353
# water chestnuts: 352
# vegetable oil cooking spray: 352
# tarragon: 351
# mangoes: 351
# ground mustard: 351
# poppy seed: 350
# dried dill: 350
# lime wedge: 348
# unbleached flour: 348
# quinoa: 348
# low-fat sour cream: 346
# marinara sauce: 346
# macadamia nuts: 346
# red food coloring: 345
# sweet paprika: 345
# cooked brown rice: 345
# toasted sesame seeds: 343
# unsweetened chocolate: 343
# creamed corn: 343
# fresh flat-leaf parsley: 343
# italian bread: 343
# red cabbage: 342
# dark sesame oil: 341
# kahlua: 341
# unflavored gelatin: 340
# fresh cilantro leaves: 340
# noodles: 340
# asiago cheese: 340
# lemon, rind of: 338
# vegetable shortening: 337
# lemongrass: 336
# nonfat sour cream: 336
# fresh parmesan cheese: 336
# pure maple syrup: 336
# low-fat cheddar cheese: 335
# lasagna noodles: 333
# sausage: 332
# instant coffee: 330
# unbleached all-purpose flour: 329
# diced onion: 328
# smoked paprika: 327
# coffee: 327
# salt & fresh ground pepper: 326
# salmon: 326
# chicken breast halves: 326
# smoked salmon: 325
# fresh asparagus: 323
# self-raising flour: 322
# mini marshmallows: 322
# lettuce leaf: 322
# sweetened flaked coconut: 322
# fresh lemon rind: 322
# white chocolate: 322
# cream-style corn: 321
# cilantro leaf: 320
# cooked turkey: 318
# miniature marshmallows: 316
# broccoli floret: 315
# maraschino cherries: 312
# greek yogurt: 312
# lemons, juice of: 311
# rice krispies: 311
# smoked sausage: 311
# bacon bits: 311
# kalamata olives: 311
# fresh breadcrumb: 310
# corn oil: 310
# chocolate: 310
# table salt: 309
# vegetables: 309
# dry yeast: 308
# light cream cheese: 308
# apricot preserves: 308
# seasoned bread crumbs: 307
# portabella mushrooms: 307
# frozen whipped topping: 305
# yukon gold potatoes: 305
# ground cayenne pepper: 305
# boneless pork chops: 302
# granny smith apple: 302
# fresh italian parsley: 302
# toasted sesame oil: 301
# mexican blend cheese: 301
# plain breadcrumbs: 300
# chili: 299
# kielbasa: 298
# diced tomato: 298
# club soda: 298
# chorizo sausage: 298
# frozen orange juice concentrate: 298
# ground chicken: 298
# low-fat mayonnaise: 297
# condensed cream of chicken soup: 296
# creole seasoning: 296
# spinach leaves: 296
# pie crusts: 296
# arborio rice: 296
# tart apples: 296
# vanilla instant pudding mix: 295
# bow tie pasta: 295
# mint leaf: 294
# turmeric powder: 294
# soft breadcrumbs: 293
# yellow pepper: 293
# fresh tomatoes: 292
# italian parsley: 290
# hazelnuts: 290
# triple sec: 289
# long-grain rice: 289
# dried thyme leaves: 288
# extra lean ground beef: 288
# tortillas: 288
# sweet onions: 288
# beef bouillon cubes: 287
# fettuccine: 287
# gorgonzola: 287
# powdered milk: 286
# olive: 286
# brewed coffee: 286
# poppy seeds: 285
# sliced water chestnuts: 284
# wide egg noodles: 284
# pearl barley: 284
# bisquick baking mix: 284
# lemon extract: 283
# cumin powder: 283
# brie cheese: 282
# fresh pineapple: 281
# ginger ale: 281
# red chili powder: 281
# fat free cream cheese: 280
# tilapia fillets: 280
# dried dill weed: 279
# fat free sour cream: 279
# dried italian seasoning: 279
# pizza dough: 278
# sunflower oil: 277
# sweet pickle relish: 276
# cardamom: 275
# beets: 274
# deli ham: 274
# white cake mix: 274
# dried oregano leaves: 273
# coriander leaves: 273
# saffron: 273
# plain low-fat yogurt: 272
# penne: 272
# rice flour: 271
# colby-monterey jack cheese: 270
# marinated artichoke hearts: 270
# arugula: 270
# baking cocoa: 269
# green chili: 269
# vidalia onion: 268
# red chilies: 268
# alfredo sauce: 266
# prawns: 266
# kale: 266
# oat bran: 264
# chipotle chile in adobo: 264
# frozen strawberries: 263
# parsnips: 259
# feta: 259
# creme fraiche: 259
# enchilada sauce: 259
# sourdough bread: 259
# baguette: 258
# pork sausage: 258
# pork: 257
# great northern beans: 257
# flank steaks: 257
# mirin: 257
# italian salad dressing: 256
# cooked white rice: 256
# dijon-style mustard: 256
# grand marnier: 255
# tomatoes and green chilies: 255
# pita bread: 255
# rotini pasta: 254
# pie crust: 254
# ranch dressing mix: 253
# instant coffee granules: 253
# frozen chopped broccoli: 253
# fresh garlic cloves: 252
# asparagus spears: 252
# instant chocolate pudding mix: 251
# pistachios: 251
# chipotle chiles in adobo: 248
# ghee: 247
# whole wheat pastry flour: 246
# crystallized ginger: 246
# olive oil flavored cooking spray: 245
# chunky salsa: 245
# white beans: 245
# tuna in water: 245
# wild rice: 245
# peppercorns: 243
# currants: 243
# minced garlic clove: 243
# beef stew meat: 241
# smooth peanut butter: 241
# red capsicum: 241
# low fat cottage cheese: 240
# whole berry cranberry sauce: 240
# chicken bouillon cube: 240
# spring onion: 240
# cherries: 239
# wine vinegar: 239
# picante sauce: 238
# limes, juice of: 237
# saltine crackers: 237
# dried cherries: 237
# sliced ripe olives: 236
# oregano leaves: 236
# fish fillets: 236
# orange, zest of: 236
# dried apricots: 236
# radishes: 236
# mixed salad greens: 236
# sherry wine vinegar: 236
# english cucumber: 235
# grenadine: 235
# corn kernels: 235
# fresh broccoli: 235
# condensed tomato soup: 235
# fat-free mayonnaise: 234
# golden syrup: 234
# instant rice: 234
# soya sauce: 234
# red chile: 233
# nonfat dry milk powder: 233
# rice wine: 233
# white onions: 232
# ground almonds: 232
# black-eyed peas: 231
# salted butter: 231
# oreo cookies: 230
# pineapple tidbits: 230
# coleslaw mix: 230
# guacamole: 230
# low-fat buttermilk: 229
# turkey: 229
# coriander powder: 229
# lemon, juice and zest of: 229
# extra-sharp cheddar cheese: 228
# superfine sugar: 228
# fresh tomato: 227
# vanilla bean: 227
# canned tomatoes: 227
# plum tomato: 227
# sweet chili sauce: 227
# sugar substitute: 226
# hot dogs: 226
# summer squash: 226
# lemon slice: 226
# crunchy peanut butter: 225
# coriander seed: 223
# chili flakes: 223
# fettuccine pasta: 222
# green food coloring: 222
# wonton wrappers: 221
# sea scallops: 221
# fresh mozzarella cheese: 219
# graham crackers: 218
# mixed vegetables: 218
# english muffins: 218
# spicy brown mustard: 217
# frozen corn kernels: 217
# barley: 217
# chicken bouillon: 217
# french-fried onions: 216
# plain nonfat yogurt: 216
# mascarpone cheese: 216
# dried breadcrumbs: 215
# dried basil leaves: 215
# fresh thyme leave: 215
# condensed milk: 214
# plain fat-free yogurt: 214
# amaretto: 214
# pancetta: 213
# pork and beans: 212
# cantaloupe: 212
# pear: 211
# baked beans: 211
# bok choy: 211
# olives: 210
# round steaks: 210
# desiccated coconut: 210
# reduced-fat sour cream: 210
# mild cheddar cheese: 209
# salted peanuts: 209
# diced tomatoes with juice: 209
# tamari: 209
# cooked shrimp: 208
# lump crabmeat: 208
# reduced-fat cream cheese: 207
# sun-dried tomato packed in oil: 207
# mint leaves: 206
# brussels sprouts: 206
# skinless chicken breasts: 206
# chuck roast: 206
# devil's food cake mix: 205
# ritz crackers: 205
# puff pastry: 205
# long-grain white rice: 205
# cardamom pods: 204
# frozen raspberries: 204
# part-skim ricotta cheese: 203
# light olive oil: 203
# frozen broccoli: 203
# cauliflower florets: 203
# liquid honey: 203
# ground lamb: 202
# bicarbonate of soda: 202
# mini chocolate chip: 202
# mint sprig: 202
# crouton: 201
# pumpkin seeds: 201
# apricot jam: 201
# vanilla yogurt: 200
# honey mustard: 200
# low-fat cream cheese: 200
# rotel tomatoes: 200
# dark soy sauce: 200
# anchovy fillets: 199
# extra firm tofu: 199
# green peas: 198
# chicken drumsticks: 198
# double cream: 198
# light coconut milk: 198
# ground flax seeds: 197
# whole chickens: 197
# reduced-sodium fat-free chicken broth: 196
# fresh spinach leaves: 195
# thyme leaves: 195
# fresh raspberry: 195
# five-spice powder: 194
# potato chips: 194
# roma tomato: 193
# crisco: 193
# pitted black olives: 193
# ice water: 193
# fine dry breadcrumb: 193
# berries: 192
# lean ground turkey: 192
# saffron thread: 192
# fruit: 191
# raw shrimp: 191
# red chili pepper: 190
# rolls: 189
# raspberry jam: 189
# chinese five spice powder: 189
# cumin seeds: 189
# stewing beef: 188
# scallops: 188
# corned beef: 188
# fresh breadcrumbs: 188
# taco sauce: 187
# miniature semisweet chocolate chips: 187
# ziti pasta: 187
# instant minced onion: 187
# green chili peppers: 187
# mango chutney: 187
# rigatoni pasta: 187
# herbes de provence: 187
# cracker: 186
# sake: 186
# graham cracker crust: 186
# crescent rolls: 186
# acorn squash: 186
# chili pepper: 186
# corn kernel: 185
# peppermint extract: 185
# chow mein noodles: 185
# chocolate cake mix: 185
# vanilla wafers: 184
# imitation crabmeat: 184
# beef bouillon granules: 184
# miniature marshmallow: 184
# watermelon: 184
# smoked ham: 184
# pitted dates: 183
# salad greens: 183
# lard: 183
# pimiento: 183
# artificial sweetener: 182
# tea bags: 182
# button mushroom: 182
# prepared yellow mustard: 181
# ramen noodles: 181
# pimientos: 181
# turkey breast: 181
# chili-garlic sauce: 180
# star anise: 180

# %%
# Plotting the first bar plot for ingredients
plt.figure(figsize=(12, 8))  # Adjust the figure size as needed
plt.subplot(2, 1, 1)  # Create subplot 1 (rows, columns, plot_number)
x_cu = [cu for cu, frq in ingredient_counts.most_common(30)]
y_frq = [frq for cu, frq in ingredient_counts.most_common(30)]
fbar = sns.barplot(x=x_cu, y=y_frq)
plt.xticks(rotation=90)  # Rotate x-axis labels

# Adding labels and title for the first subplot
plt.xlabel('Ingredients')
plt.ylabel('Frequency')
plt.title('Top 30 Most Common Ingredients')

# Plotting the second bar plot for techniques
plt.subplot(2, 1, 2)  # Create subplot 2 (rows, columns, plot_number)
x_cu2 = [cu for cu, frq in technique_counts.most_common(20)]
y_frq2 = [frq for cu, frq in technique_counts.most_common(20)]
fbar2 = sns.barplot(x=x_cu2, y=y_frq2)
plt.xticks(rotation=90)  # Rotate x-axis labels

# Adding labels and title for the second subplot
plt.xlabel('Techniques')
plt.ylabel('Frequency')
plt.title('Top 20 Most Common Techniques')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
# Initialize a defaultdict to store the number of ingredients per technique
num_ingredients = defaultdict(list)

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    techniques = eval(row['techniques_list'] ) # Access techniques directly as a list
    ingredients = eval(row['ingredients'])  # Evaluate the ingredients string to a list
    
    for technique in techniques:
        num_ingredients[technique].append(ingredients)

# Print the number of techniques (unique keys in num_ingredients)
print(f"Number of techniques: {len(num_ingredients)}\n")


# Iterate through num_ingredients and print the number of recipes per technique
count = 0
for technique, ingredient_lists in num_ingredients.items():
    print(f"{technique}: {len(ingredient_lists)} recipes")
    count += 1
    if count == 5:
        break
# Out:
# Number of techniques: 57
#
# bake: 64821 recipes
# grate: 5584 recipes
# melt: 30865 recipes
# pour: 48747 recipes
# whisk: 16467 recipes

# %%
sentences = []
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
regex = re.compile('[^a-zA-Z ]')

# Define common ingredients to filter out
#common_ingredients_to_avoid = ['salt', 'sugar', 'water', 'pepper', 'butter', 'onion', 'garlic', 'oil', 'parsley']
common_ingredients_to_avoid = []

# Function to clean and filter ingredients
def clean_ingredient(ingredient):
    cleaned_ingredient = regex.sub('', ingredient.lower()).strip()
    cleaned_words = []
    
    for word in cleaned_ingredient.split():
        if word in common_ingredients_to_avoid:
            cleaned_words = []
            break
        elif len(word) > 2 and word not in stop_words:
            cleaned_words.append(lemmatizer.lemmatize(word))
    
    return cleaned_words

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    clean_recipe = []
    ingredients = eval(row['ingredients'])
    
    for ingredient in ingredients:
        cleaned_words = clean_ingredient(ingredient)
        if cleaned_words:  # Check if cleaned_words is not empty
            clean_recipe.append(" ".join(cleaned_words))
        
    sentences.append(clean_recipe)

# Print the number of recipes processed
print(f"Number of recipes cleaned: {len(sentences)}")
print(sentences[:5])
# Out:
# Number of recipes cleaned: 178265
# [['winter squash', 'mexican seasoning', 'mixed spice', 'honey', 'butter', 'olive oil', 'salt'], ['prepared pizza crust', 'sausage patty', 'egg', 'milk', 'salt pepper', 'cheese'], ['spreadable cheese garlic herb', 'new potato', 'shallot', 'parsley', 'tarragon', 'olive oil', 'red wine vinegar', 'salt', 'pepper', 'red bell pepper', 'yellow bell pepper'], ['milk', 'vanilla ice cream', 'frozen apple juice concentrate', 'apple'], ['fennel seed', 'green olive', 'ripe olive', 'garlic', 'peppercorn', 'orange rind', 'orange juice', 'red chile', 'extra virgin olive oil']]

# %%
# Flatten the list of lists
ingredients_corpus = [ingredient for sublist in sentences for ingredient in sublist]

# Tokenize each ingredient (assuming simple split by space)
tokenized_corpus = [ingredient.split() for ingredient in ingredients_corpus]

# Set values for Word2Vec parameters
num_features = 100     # Example dimensionality of word vectors
min_word_count = 1     # Consider all words, even if they appear only once
num_workers = 4        # Number of threads to run in parallel
context = 5            # Context window size

# Train the Word2Vec model
model = Word2Vec(tokenized_corpus, vector_size=num_features, min_count=min_word_count, workers=num_workers, window=context)

# Create a dictionary to store word vectors
ingredient_vectors = {}
for ingredient in ingredients_corpus:
    words = ingredient.split()
    if words:
        ingredient_vectors[ingredient] = np.mean([model.wv[word] for word in words], axis=0)

# Normalize the vectors using MinMaxScaler
scaler = MinMaxScaler()
scaled_vectors = scaler.fit_transform(list(ingredient_vectors.values()))

# Print scaled vectors
# for ingredient, vector in zip(ingredient_vectors.keys(), scaled_vectors):
#    print(f"{ingredient}: {vector}")

# %%
print(model.wv.similarity('spaghetti', 'pasta'))
# Out:
# 0.5843064

# %%
similar_ingredients = model.wv.most_similar('spaghetti')
print('Ingredients most similar to milk:')
for ingredient, score in similar_ingredients:
    print(f'{ingredient}: {score}')
# Out:
# Ingredients most similar to milk:
# carnation: 0.5658212900161743
# soymilk: 0.4907117784023285
# desiccated: 0.489478200674057
# drinking: 0.478114515542984
# flaked: 0.46274086833000183
# replacer: 0.4623143672943115
# carob: 0.4434153437614441
# eagle: 0.4358048737049103
# file: 0.4308757483959198
# ricotta: 0.4300636947154999

# %%
# Group techniques to form corpus
technique_corpus = [[technique] for technique in raw_techniques]

# Tokenize each technique
tokenized_techniques = [technique.split() for technique in raw_techniques]

# Train the Word2Vec model for techniques
technique_model = Word2Vec(tokenized_techniques, vector_size=num_features, min_count=min_word_count, workers=num_workers, window=context)

# Create a dictionary to store technique vectors
technique_vectors = {technique: np.mean([technique_model.wv[word] for word in technique.split()], axis=0) for technique in raw_techniques}

# Normalize the technique vectors
scaled_technique_vectors = scaler.fit_transform(list(technique_vectors.values()))

# Elbow method to determine the optimal number of clusters for techniques
distortions = []
K = range(1, 15)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(scaled_technique_vectors)
    distortions.append(sum(np.min(cdist(scaled_technique_vectors, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / scaled_technique_vectors.shape[0])

# Plot the elbow for techniques
plt.figure()
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k for techniques')
plt.show()

# Perform KMeans clustering on techniques
num_clusters_techniques = len(TECHNIQUES_LIST)
kmeans_technique_clustering = KMeans(n_clusters=num_clusters_techniques)
technique_idx = kmeans_technique_clustering.fit_predict(scaled_technique_vectors)

# Assign clusters to techniques
technique_assignments = list(zip(technique_vectors.keys(), technique_idx))
print('Technique Cluster assignments:')
for technique, cluster in technique_assignments:
    print(f'{technique}: Cluster {cluster}')
# Out:
# Technique Cluster assignments:
# bake: Cluster 9
# grate: Cluster 4
# melt: Cluster 5
# pour: Cluster 9
# whisk: Cluster 9
# boil: Cluster 4
# dice: Cluster 4
# drain: Cluster 5
# blend: Cluster 0
# combine: Cluster 9
# smooth: Cluster 5
# crush: Cluster 0
# marinate: Cluster 0
# refrigerate: Cluster 0
# toast: Cluster 10
# freeze: Cluster 10
# whip: Cluster 6
# simmer: Cluster 10
# crock pot: Cluster 2
# skillet: Cluster 9
# fry: Cluster 4
# toss: Cluster 10
# puree: Cluster 5
# saute: Cluster 10
# thicken: Cluster 7
# slow cook: Cluster 3
# deglaze: Cluster 4
# grill: Cluster 10
# smoke: Cluster 0
# strain: Cluster 6
# mash: Cluster 10
# pickle: Cluster 0
# soak: Cluster 9
# stew: Cluster 5
# knead: Cluster 0
# microwave: Cluster 5
# roast: Cluster 9
# steam: Cluster 5
# broil: Cluster 4
# shred: Cluster 0
# scramble: Cluster 10
# barbecue: Cluster 0
# caramelize: Cluster 8
# scald: Cluster 6
# devein: Cluster 9
# griddle: Cluster 0
# parboil: Cluster 0
# emulsify: Cluster 4
# braise: Cluster 5
# blanch: Cluster 5
# brine: Cluster 9
# pressure cook: Cluster 1
# ferment: Cluster 0
# poach: Cluster 6
# tenderize: Cluster 7
# leaven: Cluster 9
# distill: Cluster 9

# %%
technique_cluster_map = {technique: cluster for technique, cluster in technique_assignments}

ingredients_per_technique_cluster = defaultdict(list)
techniques_per_technique_cluster = defaultdict(list)

for index, row in data.iterrows():
    ingredients = eval(row['ingredients'])
    techniques = eval(row['techniques_list'])
    for technique in techniques:
        cluster = technique_cluster_map.get(technique)
        if cluster is not None:
            ingredients_per_technique_cluster[cluster].extend(ingredients)
            techniques_per_technique_cluster[cluster].extend(techniques)

dominant_techniques_per_cluster = {cluster: Counter(techniques).most_common(1)[0][0] for cluster, techniques in
                                   techniques_per_technique_cluster.items()}
cluster_to_method = {cluster: technique for cluster, technique in dominant_techniques_per_cluster.items()}

ingredient_cluster_map = {ingredient: kmeans_technique_clustering.predict(
    scaler.transform([np.mean([model.wv[word] for word in ingredient.split()], axis=0)]))[0] for ingredient in
                          ingredients_corpus}

# %%
def clean_ingredient(ingredient):
    cleaned_ingredient = regex.sub('', ingredient.lower()).strip()
    cleaned_words = []
    
    for word in cleaned_ingredient.split():
        if word in common_ingredients_to_avoid:
            cleaned_words = []
            break
        elif len(word) > 2 and word not in stop_words:
            cleaned_words.append(lemmatizer.lemmatize(word))
    
    return cleaned_words

# %%
def get_dominant_cooking_methods(ingredients, ingredient_cluster_map, cluster_to_method, ingredient_counts):
    method_counts = Counter()
    total_ingredient_count = sum(ingredient_counts.values())
    
    # Clean and filter ingredients
    cleaned_ingredients = []
    for ingredient in ingredients:
        cleaned_words = clean_ingredient(ingredient)
        if cleaned_words:  # Check if cleaned_words is not empty
            cleaned_ingredients.append(" ".join(cleaned_words))
    
    # Calculate relative importance weights for each ingredient based on its frequency
    weights = {ingredient: ingredient_counts.get(ingredient, 0) / total_ingredient_count for ingredient in cleaned_ingredients}
    
    # Calculate method counts using the mapped techniques
    for ingredient in cleaned_ingredients:
        cluster = ingredient_cluster_map.get(ingredient)
        if cluster is not None:
            method = cluster_to_method.get(cluster)
            if method:
                mapped_method = technique_mapping.get(method)
                if mapped_method:
                    method_counts[mapped_method] += weights[ingredient]
    
    # Normalize method counts
    if method_counts:
        max_count = max(method_counts.values())
        method_counts = {method: count / max_count for method, count in method_counts.items()}
    
    # Get top 3 methods from TECHNIQUES_LIST
    top_methods = sorted(method_counts.items(), key=lambda x: x[1], reverse=True)[:3]
    
    # Determine the most important ingredient based on weights
    most_important_ingredient = max(cleaned_ingredients, key=lambda x: weights.get(x, 0))
    
    return [method for method, _ in top_methods], most_important_ingredient

# %%
ingredients_list_1 = ['chicken', 'potato', 'oil', 'water', 'butter', 'onion', 'garlic', 'salt', 'pepper', 'parsley']
dominant_methods_1, important_ingredient_1 = get_dominant_cooking_methods(ingredients_list_1, ingredient_cluster_map, cluster_to_method, ingredient_counts)
print(f"Top cooking methods for the given ingredients (emphasis on '{important_ingredient_1}'): {dominant_methods_1}")

ingredients_list_2 = ['pasta', 'tomato', 'onion', 'garlic', 'cheese', 'olive oil', 'basil', 'salt', 'pepper', 'parsley']
dominant_methods_2, important_ingredient_2 = get_dominant_cooking_methods(ingredients_list_2, ingredient_cluster_map, cluster_to_method, ingredient_counts)
print(f"Top cooking methods for the given ingredients (emphasis on '{important_ingredient_2}'): {dominant_methods_2}")
